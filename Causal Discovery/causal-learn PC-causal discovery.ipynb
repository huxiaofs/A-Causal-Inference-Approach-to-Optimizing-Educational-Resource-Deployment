# %%
from causallearn.search.ConstraintBased.PC import pc
from causallearn.utils.GraphUtils import GraphUtils
from causallearn.utils.cit import fisherz
import networkx as nx
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
data = pd.read_csv(r'D:\wechat\WeChat Files\wxid_1ec8qk54xebz22\FileStorage\File\2024-03\dataset3.csv')
labels = data.columns.tolist()
data = data.to_numpy()

# %%
file_path = "pc_output_edgelist_test-dataset3.txt"
result_path = "causal_learn_causal_graph_pc_test-dataset3.png"

# %%
cg = pc(data)
# Out:
#   0%|          | 0/9 [00:00<?, ?it/s]

# %%
cg.draw_pydot_graph()

# %%
pyd = GraphUtils.to_pydot(cg.G, labels=labels)
pyd.write_png(result_path)
